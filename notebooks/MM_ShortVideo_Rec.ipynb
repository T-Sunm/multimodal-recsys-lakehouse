# %%
# !git clone https://github.com/T-Sunm/MM-ShortVideo-Rec.git

# %cd MM-ShortVideo-Rec
# Out:
# Cloning into 'MM-ShortVideo-Rec'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 49 (delta 23), reused 39 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (49/49), 115.50 KiB | 14.44 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# /content/MM-ShortVideo-Rec/MM-ShortVideo-Rec

# %%
# 1. Tải toàn bộ thư mục từ Drive về folder tên là 'dataset'
# !gdown --folder https://drive.google.com/drive/folders/156RLMeYhBh_0uE3JpLNpP9RIpvkOWqt1?usp=sharing -O dataset

# 2. Di chuyển vào thư mục dataset và giải nén cover.zip
# Lệnh này sẽ giải nén nội dung cover.zip ngay tại folder dataset
# !unzip -q dataset/covers.zip -d dataset/

# 3. Kiểm tra lại cấu trúc thư mục để đảm bảo các file đã nằm chung với nhau
# !ls -lh dataset/
# Out:
# Retrieving folder contents
# Processing file 1CjSXJcPculTwhP14_bjbdlmTdMOHBR61 covers.zip
# Processing file 1wD4o_pXmX-O5wpOtrTyd5hMwAGzbJHYf likes_and_views.txt
# Processing file 1t50Ok20QvoGU4ZzYBhnaHBdctMp6ecP2 pairs.csv
# Processing file 1r2xIJcjpEeDFqu2CvWiWtfa9SKPnIHQc titles.csv
# Processing file 1hidAqCy-zIJ2uHj4vPqwJQNr0n1lY02q visual_embeddings.pt
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1CjSXJcPculTwhP14_bjbdlmTdMOHBR61
# From (redirected): https://drive.google.com/uc?id=1CjSXJcPculTwhP14_bjbdlmTdMOHBR61&confirm=t&uuid=77c9a974-93f2-4bc9-adcb-586fb9dd23ce
# To: /content/MM-ShortVideo-Rec/dataset/covers.zip
# 100% 176M/176M [00:01<00:00, 102MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1wD4o_pXmX-O5wpOtrTyd5hMwAGzbJHYf
# To: /content/MM-ShortVideo-Rec/dataset/likes_and_views.txt
# 100% 103k/103k [00:00<00:00, 54.8MB/s]
# ...

# %%
# !mkdir /content/checkpoints

# %%
# !pip install .
# Out:
# Processing /content/MM-ShortVideo-Rec
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 129.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 125.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 10.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.7/530.7 MB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.5/196.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 MB 20.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 MB 2.6 MB/s eta 0:00:00
# ...

# %%
# %cd /content/MM-ShortVideo-Rec
# !python src/train.py \
  --data_dir /content/MM-ShortVideo-Rec/dataset \
  --checkpoint_dir /content/checkpoints \
  --num_epoch 1 \
  --use_cuda
# Out:
# /content/MM-ShortVideo-Rec
# Range of userId is [0, 19999]
# Range of itemId is [0, 4998]
# Embedding(20000, 8)
# Embedding(4999, 8)
# Embedding(20000, 8)
# Embedding(4999, 8)
# Linear(in_features=16, out_features=64, bias=True)
# Linear(in_features=64, out_features=32, bias=True)
# Linear(in_features=32, out_features=16, bias=True)
# Linear(in_features=16, out_features=8, bias=True)
# Linear(in_features=776, out_features=8, bias=True)
# Linear(in_features=776, out_features=8, bias=True)
# Linear(in_features=16, out_features=1, bias=True)
# NeuMF(
#   (embedding_user_mlp): Embedding(20000, 8)
#   (embedding_item_mlp): Embedding(4999, 8)
#   (embedding_user_mf): Embedding(20000, 8)
#   (embedding_item_mf): Embedding(4999, 8)
#   (fc_layers): ModuleList(
#     (0): Linear(in_features=16, out_features=64, bias=True)
#     (1): Linear(in_features=64, out_features=32, bias=True)
#     (2): Linear(in_features=32, out_features=16, bias=True)
# ...

# %%
# !python src/train.py \
  --data_dir /content/MM-ShortVideo-Rec/dataset \
  --checkpoint_dir /content/checkpoints \
  --num_epoch 1 \
  --use_cuda \
  --no_visual
# Out:
# Range of userId is [0, 19999]
# Range of itemId is [0, 4998]
# Embedding(20000, 8)
# Embedding(4999, 8)
# Embedding(20000, 8)
# Embedding(4999, 8)
# Linear(in_features=16, out_features=64, bias=True)
# Linear(in_features=64, out_features=32, bias=True)
# Linear(in_features=32, out_features=16, bias=True)
# Linear(in_features=16, out_features=8, bias=True)
# Linear(in_features=16, out_features=1, bias=True)
# NeuMF(
#   (embedding_user_mlp): Embedding(20000, 8)
#   (embedding_item_mlp): Embedding(4999, 8)
#   (embedding_user_mf): Embedding(20000, 8)
#   (embedding_item_mf): Embedding(4999, 8)
#   (fc_layers): ModuleList(
#     (0): Linear(in_features=16, out_features=64, bias=True)
#     (1): Linear(in_features=64, out_features=32, bias=True)
#     (2): Linear(in_features=32, out_features=16, bias=True)
#     (3): Linear(in_features=16, out_features=8, bias=True)
#   )
#   (affine_output): Linear(in_features=16, out_features=1, bias=True)
#   (logistic): Sigmoid()
# )
# ...

# %%
# !python src/inference.py \
  --data_dir /content/MM-ShortVideo-Rec/dataset \
  --checkpoint /content/checkpoints/neumf_factor8neg4_Epoch1...model \
  --user_id "12" \
  --top_k 5 \
  --use_cuda
